# %%
pwd
# Out:
# 'C:\\Users\\mufliha jahan'

# %%
# Import  the required libraries
import pandas as pd 
import numpy 
import sklearn
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
# Loading the dataset file
df1=pd.read_csv("music.csv")

# %%
df1
# Out:
#             filename  chroma_stft      rmse  spectral_centroid  \
# 0    blues.00000.wav     0.349943  0.130225        1784.420446
# 1    blues.00001.wav     0.340983  0.095918        1529.835316
# 2    blues.00002.wav     0.363603  0.175573        1552.481958
# 3    blues.00003.wav     0.404779  0.141191        1070.119953
# 4    blues.00004.wav     0.308590  0.091563        1835.494603
# ..               ...          ...       ...                ...
# 995   rock.00095.wav     0.351991  0.079469        2008.581132
# 996   rock.00096.wav     0.398653  0.076452        2006.051164
# 997   rock.00097.wav     0.432103  0.081617        2077.190361
# 998   rock.00098.wav     0.362349  0.083888        1398.672358
# 999   rock.00099.wav     0.358195  0.054461        1609.442919
#
#      spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0           2002.650192  3806.485316            0.083066 -113.596748
# 1           2038.617579  3548.820207            0.056044 -207.556793
# 2           1747.165985  3040.514948            0.076301  -90.754387
# 3           1596.333948  2185.028454            0.033309 -199.431152
# 4           1748.362448  3580.945013            0.101500 -160.266037
# ..                  ...          ...                 ...         ...
# 995         2106.617024  4254.215942            0.089267 -153.632309
# 996         2068.327905  4147.374921            0.097659 -142.424210
# 997         1926.989678  4030.767293            0.121824 -125.031311
# 998         1818.148469  3014.740104            0.048731 -224.972305
# 999         1797.065098  3246.280370            0.076290 -235.189331
#
#           mfcc2      mfcc3  ...     mfcc12     mfcc13    mfcc14     mfcc15  \
# 0    121.557297 -19.158825  ...   8.810669  -3.667368  5.751691  -5.162763
# 1    124.006721   8.930560  ...   5.376803  -2.239120  4.216963  -6.012273
# 2    140.459900 -29.109968  ...   5.789265  -8.905224 -1.083720  -9.218359
# 3    150.099213   5.647593  ...   6.087677  -2.476421 -1.073890  -2.874778
# 4    126.198807 -35.605450  ...  -2.806384  -6.934123 -7.558618  -9.173553
# ..          ...        ...  ...        ...        ...       ...        ...
# 995  109.857262 -23.085709  ...  12.350816 -12.306271  5.780973 -10.279924
# 996  116.219780 -32.177074  ...  14.065345 -16.394691  4.152589  -4.350760
# 997  115.194977 -47.993507  ...  10.481961 -17.951916  1.211113 -11.534864
# 998  123.656891  -9.754534  ...   7.683081 -10.071786 -0.255098  -5.276486
# 999  123.888542 -22.536184  ...  10.066771 -15.019588  3.110468  -7.127754
#
#        mfcc16     mfcc17    mfcc18     mfcc19     mfcc20  label
# 0    0.750948  -1.691938 -0.409953  -2.300209   1.219929  blues
# 1    0.936110  -0.716537  0.293876  -0.287431   0.531573  blues
# 2    2.455806  -7.726901 -1.815723  -3.433434  -2.226821  blues
# 3    0.780977  -3.316932  0.637982  -0.619690  -3.408233  blues
# 4   -4.512165  -5.453538 -0.924161  -4.409333 -11.703781  blues
# ..        ...        ...       ...        ...        ...    ...
# 995  1.791489 -13.304210  2.473193  -6.717574  -1.189238   rock
# 996  3.736455 -10.845638  1.875218  -7.459579  -2.802677   rock
# 997  1.844774 -12.847901  3.447425 -12.594178  -2.107002   rock
# 998 -2.816289  -4.416438  1.558265  -5.043121  -3.585596   rock
# 999  1.784515  -7.070405  0.023643  -2.022034   1.158525   rock
#
# [1000 rows x 28 columns]

# %%
# Display The names of all the columns in the data.
df1.columns.values
# Out:
# array(['filename', 'chroma_stft', 'rmse', 'spectral_centroid',
#        'spectral_bandwidth', 'rolloff', 'zero_crossing_rate', 'mfcc1',
#        'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5', 'mfcc6', 'mfcc7', 'mfcc8',
#        'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12', 'mfcc13', 'mfcc14',
#        'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19', 'mfcc20',
#        'label'], dtype=object)

# %%
df1.label.value_counts()
# Out:
# rock         100
# reggae       100
# hiphop       100
# pop          100
# metal        100
# blues        100
# classical    100
# country      100
# jazz         100
# disco        100
# Name: label, dtype: int64

# %%
# Display the total number of rows in the dataset
len(df1)
# Out:
# 1000

# %%
# Choose genres
value_list = ['blues','classical','country','disco','hiphop','jazz','metal','pop','reggae','rock']
# Grab DataFrame rows where column has values from "value_list" defined above
df1= df1.loc[df1.label.isin(value_list)]

# %%
df1
# Out:
#             filename  chroma_stft      rmse  spectral_centroid  \
# 0    blues.00000.wav     0.349943  0.130225        1784.420446
# 1    blues.00001.wav     0.340983  0.095918        1529.835316
# 2    blues.00002.wav     0.363603  0.175573        1552.481958
# 3    blues.00003.wav     0.404779  0.141191        1070.119953
# 4    blues.00004.wav     0.308590  0.091563        1835.494603
# ..               ...          ...       ...                ...
# 995   rock.00095.wav     0.351991  0.079469        2008.581132
# 996   rock.00096.wav     0.398653  0.076452        2006.051164
# 997   rock.00097.wav     0.432103  0.081617        2077.190361
# 998   rock.00098.wav     0.362349  0.083888        1398.672358
# 999   rock.00099.wav     0.358195  0.054461        1609.442919
#
#      spectral_bandwidth      rolloff  zero_crossing_rate       mfcc1  \
# 0           2002.650192  3806.485316            0.083066 -113.596748
# 1           2038.617579  3548.820207            0.056044 -207.556793
# 2           1747.165985  3040.514948            0.076301  -90.754387
# 3           1596.333948  2185.028454            0.033309 -199.431152
# 4           1748.362448  3580.945013            0.101500 -160.266037
# ..                  ...          ...                 ...         ...
# 995         2106.617024  4254.215942            0.089267 -153.632309
# 996         2068.327905  4147.374921            0.097659 -142.424210
# 997         1926.989678  4030.767293            0.121824 -125.031311
# 998         1818.148469  3014.740104            0.048731 -224.972305
# 999         1797.065098  3246.280370            0.076290 -235.189331
#
#           mfcc2      mfcc3  ...     mfcc12     mfcc13    mfcc14     mfcc15  \
# 0    121.557297 -19.158825  ...   8.810669  -3.667368  5.751691  -5.162763
# 1    124.006721   8.930560  ...   5.376803  -2.239120  4.216963  -6.012273
# 2    140.459900 -29.109968  ...   5.789265  -8.905224 -1.083720  -9.218359
# 3    150.099213   5.647593  ...   6.087677  -2.476421 -1.073890  -2.874778
# 4    126.198807 -35.605450  ...  -2.806384  -6.934123 -7.558618  -9.173553
# ..          ...        ...  ...        ...        ...       ...        ...
# 995  109.857262 -23.085709  ...  12.350816 -12.306271  5.780973 -10.279924
# 996  116.219780 -32.177074  ...  14.065345 -16.394691  4.152589  -4.350760
# 997  115.194977 -47.993507  ...  10.481961 -17.951916  1.211113 -11.534864
# 998  123.656891  -9.754534  ...   7.683081 -10.071786 -0.255098  -5.276486
# 999  123.888542 -22.536184  ...  10.066771 -15.019588  3.110468  -7.127754
#
#        mfcc16     mfcc17    mfcc18     mfcc19     mfcc20  label
# 0    0.750948  -1.691938 -0.409953  -2.300209   1.219929  blues
# 1    0.936110  -0.716537  0.293876  -0.287431   0.531573  blues
# 2    2.455806  -7.726901 -1.815723  -3.433434  -2.226821  blues
# 3    0.780977  -3.316932  0.637982  -0.619690  -3.408233  blues
# 4   -4.512165  -5.453538 -0.924161  -4.409333 -11.703781  blues
# ..        ...        ...       ...        ...        ...    ...
# 995  1.791489 -13.304210  2.473193  -6.717574  -1.189238   rock
# 996  3.736455 -10.845638  1.875218  -7.459579  -2.802677   rock
# 997  1.844774 -12.847901  3.447425 -12.594178  -2.107002   rock
# 998 -2.816289  -4.416438  1.558265  -5.043121  -3.585596   rock
# 999  1.784515  -7.070405  0.023643  -2.022034   1.158525   rock
#
# [700 rows x 28 columns]

# %%
# Choose the most affecting features (Uncomment the line below)
#x = df1.drop('label',1)

# Choose class (genre of music) for training and testing
y = df1['label']

#Choose features (audio features) for , training, and ,testing (all, 11, features)
x = df1[['chroma_stft' ,'rmse' ,'spectral_centroid', 'spectral_bandwidth',
 'rolloff' ,'zero_crossing_rate' ,'mfcc1' ,'mfcc2', 'mfcc3', 'mfcc4', 'mfcc5',
 'mfcc6','mfcc7' ,'mfcc8', 'mfcc9', 'mfcc10', 'mfcc11', 'mfcc12', 'mfcc13',
 'mfcc14' ,'mfcc15', 'mfcc16', 'mfcc17', 'mfcc18', 'mfcc19' ,'mfcc20']]

# %%
x
# Out:
#      chroma_stft      rmse  spectral_centroid  spectral_bandwidth  \
# 0       0.349943  0.130225        1784.420446         2002.650192
# 1       0.340983  0.095918        1529.835316         2038.617579
# 2       0.363603  0.175573        1552.481958         1747.165985
# 3       0.404779  0.141191        1070.119953         1596.333948
# 4       0.308590  0.091563        1835.494603         1748.362448
# ..           ...       ...                ...                 ...
# 995     0.351991  0.079469        2008.581132         2106.617024
# 996     0.398653  0.076452        2006.051164         2068.327905
# 997     0.432103  0.081617        2077.190361         1926.989678
# 998     0.362349  0.083888        1398.672358         1818.148469
# 999     0.358195  0.054461        1609.442919         1797.065098
#
#          rolloff  zero_crossing_rate       mfcc1       mfcc2      mfcc3  \
# 0    3806.485316            0.083066 -113.596748  121.557297 -19.158825
# 1    3548.820207            0.056044 -207.556793  124.006721   8.930560
# 2    3040.514948            0.076301  -90.754387  140.459900 -29.109968
# 3    2185.028454            0.033309 -199.431152  150.099213   5.647593
# 4    3580.945013            0.101500 -160.266037  126.198807 -35.605450
# ..           ...                 ...         ...         ...        ...
# 995  4254.215942            0.089267 -153.632309  109.857262 -23.085709
# 996  4147.374921            0.097659 -142.424210  116.219780 -32.177074
# 997  4030.767293            0.121824 -125.031311  115.194977 -47.993507
# 998  3014.740104            0.048731 -224.972305  123.656891  -9.754534
# 999  3246.280370            0.076290 -235.189331  123.888542 -22.536184
#
#          mfcc4  ...     mfcc11     mfcc12     mfcc13    mfcc14     mfcc15  \
# 0    42.351028  ...  -8.324325   8.810669  -3.667368  5.751691  -5.162763
# 1    35.874683  ...  -5.560388   5.376803  -2.239120  4.216963  -6.012273
# 2    31.689013  ... -13.123111   5.789265  -8.905224 -1.083720  -9.218359
# 3    26.871927  ...  -3.196314   6.087677  -2.476421 -1.073890  -2.874778
# 4    22.153301  ... -13.083821  -2.806384  -6.934123 -7.558618  -9.173553
# ..         ...  ...        ...        ...        ...       ...        ...
# 995  59.040672  ... -12.380283  12.350816 -12.306271  5.780973 -10.279924
# 996  49.122971  ... -12.982494  14.065345 -16.394691  4.152589  -4.350760
# 997  52.834530  ... -16.048916  10.481961 -17.951916  1.211113 -11.534864
# 998  56.595062  ...  -9.000731   7.683081 -10.071786 -0.255098  -5.276486
# 999  52.915512  ...  -2.940462  10.066771 -15.019588  3.110468  -7.127754
#
#        mfcc16     mfcc17    mfcc18     mfcc19     mfcc20
# 0    0.750948  -1.691938 -0.409953  -2.300209   1.219929
# 1    0.936110  -0.716537  0.293876  -0.287431   0.531573
# 2    2.455806  -7.726901 -1.815723  -3.433434  -2.226821
# 3    0.780977  -3.316932  0.637982  -0.619690  -3.408233
# 4   -4.512165  -5.453538 -0.924161  -4.409333 -11.703781
# ..        ...        ...       ...        ...        ...
# 995  1.791489 -13.304210  2.473193  -6.717574  -1.189238
# 996  3.736455 -10.845638  1.875218  -7.459579  -2.802677
# 997  1.844774 -12.847901  3.447425 -12.594178  -2.107002
# 998 -2.816289  -4.416438  1.558265  -5.043121  -3.585596
# 999  1.784515  -7.070405  0.023643  -2.022034   1.158525
#
# [700 rows x 26 columns]

# %%
y
# Out:
# 0      blues
# 1      blues
# 2      blues
# 3      blues
# 4      blues
#        ...
# 995     rock
# 996     rock
# 997     rock
# 998     rock
# 999     rock
# Name: label, Length: 700, dtype: object

# %%
len(df1)
# Out:
# 700

# %%
# Use train/test split with different random_state values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
len(X_test)
# Out:
# 175

# %%
# Create a random forest classifier
# clf means classifier
clf = RandomForestClassifier(n_estimators=10000, random_state=0, n_jobs=-1)

# Train the classifier
clf.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(n_estimators=10000, n_jobs=-1, random_state=0)

# %%
# Print the name and gini importance of each feature
for feature in zip(x, clf.feature_importances_):
    print(feature)
# Out:
# ('chroma_stft', 0.0835543765513882)
# ('rmse', 0.06861108517431044)
# ('spectral_centroid', 0.035619448938027536)
# ('spectral_bandwidth', 0.0440768757086418)
# ('rolloff', 0.03942096334154134)
# ('zero_crossing_rate', 0.03776033343460349)
# ('mfcc1', 0.05023218195277901)
# ('mfcc2', 0.031999988165812523)
# ('mfcc3', 0.03680745374105501)
# ('mfcc4', 0.05897921764593625)
# ('mfcc5', 0.030528781039671864)
# ('mfcc6', 0.03816284413956029)
# ('mfcc7', 0.03255292395085225)
# ('mfcc8', 0.03153111258504289)
# ('mfcc9', 0.04525734914213327)
# ('mfcc10', 0.024335673146068767)
# ('mfcc11', 0.03602765449644499)
# ('mfcc12', 0.031808701120442526)
# ('mfcc13', 0.03764667904002111)
# ('mfcc14', 0.026639682894132988)
# ('mfcc15', 0.03319146737251504)
# ('mfcc16', 0.02978415551832557)
# ('mfcc17', 0.0387572049351507)
# ('mfcc18', 0.02567917251123096)
# ('mfcc19', 0.02404465878077732)
# ('mfcc20', 0.026990014673533912)

# %%
# Check the number of testing examples
print(X_train.shape)
# Out:
# (525, 26)

# %%
# Classification (KNN)
# Create KNN Classifier
clf = KNeighborsClassifier(n_neighbors=23)
# Train the classifier
clf.fit(X_train, y_train.values.ravel())
# Out:
# KNeighborsClassifier(n_neighbors=23)

# %%
# Test accuracy of KNN algorithm
a = accuracy_score(clf.predict(X_test), y_test)
print('Accuracy score for KNN algorithm =',a*100,'%')
# Out:
# Accuracy score for KNN algorithm = 40.0 %

# %%
# Decision Tree Classification
# Create Decision Tree Classifier
clf = DecisionTreeClassifier(random_state=0)
# Evaluate a score by cross-validation
cross_val_score(clf, X_train, y_train.values.ravel(), cv=10)
# Out:
# array([0.58490566, 0.56603774, 0.52830189, 0.60377358, 0.37735849,
#        0.42307692, 0.55769231, 0.48076923, 0.44230769, 0.5       ])

# %%
# Train the classifier
clf.fit(X_train, y_train.values.ravel())
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
# Test accuracy of Decision Trees algorithm
a1 = accuracy_score(clf.predict(X_test), y_test)
print('Accuracy score for Decision Trees algorithm =',a1*100,'%')
# Out:
# Accuracy score for Decision Trees algorithm = 46.85714285714286 %

# %%
# Classification (Random Forest)
# Create Random Forest Classifier
clf = RandomForestClassifier(random_state=0)
# Train the classifier
clf.fit(X_train, y_train.values.ravel())
# Out:
# RandomForestClassifier(random_state=0)

# %%
# Test accuracy of Random Forest algorithm
a1 = accuracy_score(clf.predict(X_test), y_test)
print('Accuracy score for Random Forest algorithm =',a1*100,'%')
# Out:
# Accuracy score for Random Forest algorithm = 65.14285714285715 %
